# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# 라이브러리 import
import cv2
import argparse
import json
import numpy as np
import imagesize
import os
import shutil
from pathlib import Path

# %%
# 경로 이동
# %cd /content/gdrive/MyDrive/AIFactory/Task2
# Out:
# /content/gdrive/MyDrive/AIFactory/Task2

# %% [markdown]
# ### Detect
# - 학습된 가중치를 이용하여 test image detection 진행
#   - image size : 1280
#   - confidence threshold : 0.2

# %%
# !pip install -r ./yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 67.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
# !python ./yolov5/detect.py --weights ./weights/best.pt --img 1280 --source ./data/test_data/ --save-txt --conf 0.2 --name result
# Out:
# detect: weights=['./weights/best.pt'], source=./data/test_data/, data=yolov5/data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=result, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-11-6 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/25 /content/gdrive/MyDrive/AIFactory/Task2/data/test_data/image_001.jpg: 1216x1280 18 ics, 10 capacitors, 15 resistors, 1567.0ms
# image 2/25 /content/gdrive/MyDrive/AIFactory/Task2/data/test_data/image_002.jpg: 864x1280 10 ics, 21 capacitors, 6 resistors, 1417.3ms
# ...

# %% [markdown]
# ### Convert YOLO to JSON
# - yolo format으로 저장된 label file을 json 형식으로 변환

# %%
label_path = "./yolov5/runs/detect/result/labels"
label_list = os.listdir(label_path)

for i in label_list:
  shutil.copy(label_path + "/" + i, "/content/gdrive/MyDrive/AIFactory/Task2/convert_yolo_json/test/train")

# %%
# %cd /content/gdrive/MyDrive/AIFactory/Task2/convert_yolo_json
# Out:
# /content/gdrive/MyDrive/AIFactory/Task2/convert_yolo_json

# %%
from create_annotations import (
    create_image_annotation,
    create_annotation_from_yolo_format,
    create_annotation_from_yolo_results_format,
    coco_format,
)

# %%
# !python main.py --path ./test/ --output answer.json
# Out:
# Start!
# Processing 25 ...Finished!
